# %% [markdown]
# # Pandas(판다스) intro

# %% [markdown]
# ## 패키지 불러오기

# %% [markdown]
# # 데이터 읽기

# %% [markdown]
# - `read_csv(경로)`
# - `read_excel`
# - `read_json`

# %% [markdown]
# ### 상대 경로

# %% [markdown]
# `.`: 현재 경로
# `..`: 상위 경로

# %%
#참고만
import os
print(os.getcwd())
# Out:
# C:\Users\beluga\Desktop\samsung-sfds-basic1\Solutions

# %% [markdown]
# ### 절대 경로

# %% [markdown]
# ## 데이터 선택

# %% [markdown]
# ### 컬럼 기준 선택

# %% [markdown]
# # Series

# %% [markdown]
# ## 데이터 생성&조회

# %% [markdown]
# ### pd.Series

# %% [markdown]
# - 시리즈 = 인덱스(index) + data `pd.Series(data, index)`

# %% [markdown]
# - index는 딕셔너리의 Key와 비슷

# %% [markdown]
# - 인덱스 지정하지 않고 만들기

# %% [markdown]
# - 인덱스 컬럼으로 이동, 인덱스 초기화

# %% [markdown]
# [행정구역(시군구)별, 성별 인구수,kosis](https://kosis.kr/statHtml/statHtml.do?orgId=101&tblId=DT_1B040A3)

# %%
#
인구 = pd.Series([9_558_153, 3_448_737, 2_466_052], index=["서울", "부산", "대구"]) #2021 기준 #서울 9백만 
인구
# Out:
# 서울    9558153
# 부산    3448737
# 대구    2466052
# dtype: int64

# %% [markdown]
# ### index

# %% [markdown]
# ### values

# %% [markdown]
# ### sort_values()

# %% [markdown]
# ## 데이터 연산

# %% [markdown]
# ### 브로드 캐스팅

# %% [markdown]
# - 형태 확인 `shape`

# %% [markdown]
# 브로드캐스팅은 '방송'이라는 뜻도 있지만 '전파하다'라는 의미
#
# 작은 크기가 큰 크기에 맞춰 전파하다
#
# 그림과 같이 shape (1,) 크기의 값인 3이 변수 a의 shape (3,)에 맞춰 전파

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Q. 현재 인구 데이터는 단위가 명 단위이다. 백만단위로 바꾸면 읽기가 더 쉬울 거 같다. 인구 시리즈를 알맞게 바꿔보자

# %% [markdown]
# ## 데이터 집계

# %% [markdown]
# ### `unique` : 겹치지 않는 원소 (`set`과 동일)

# %% [markdown]
# ### `value_counts()` : 각 원소의 개수 카운팅

# %% [markdown]
# ### Series + Series

# %% [markdown]
# q. 눈으로 풀어봅시다 s1 + s2를 하면 결과가 어떻게 될까요? 1번 5,5,5 vs. 2번 3,6,6

# %% [markdown]
# ## 데이터 선택

# %% [markdown]
# ### indexing- isin, boolean indexing

# %% [markdown]
# - basic
#     - 인덱스 기준으로 데이터 가져옴
#     - Series의 `[ ]` 연산자: 인덱스, 인덱스로 변환 가능한 표현식을 넣을 수 있음

# %% [markdown]
# - isin

# %% [markdown]
# q. 고객성별이 여자인 인덱스는?

# %% [markdown]
# - 불린 인덱싱
# 불리언을 이용해서 인덱싱
# True 인덱스를 가져옴

# %% [markdown]
# q. 고객성별이 남자인 인덱스는?
#
# False 인덱스를 가져옴

# %% [markdown]
# ### 슬라이싱

# %% [markdown]
# 판다스에는 `명시적인 인덱스` 와 `암묵적인 인덱스` 가 있습니다.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# - 명시적 인덱스
#     - 눈에 보이는 인덱스를 이용

# %% [markdown]
# - 암묵적 인덱스

# %% [markdown]
# - 암묵적인 인덱스가 명시적인 인덱스보다 우선순위를 가진다

# %% [markdown]
# q.위에서 차례로 데이터 3개만 추출하라

# %% [markdown]
# 제대로 알고 있으면 괜찮겠지만 보통 헷갈린다.
#
# 그래서 Pandas 는 특정 인덱싱 방식을 드러내는 몇 가지 특별한 인덱서 (indexer) 속성을 제공한다.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 데이터 편집

# %% [markdown]
# - 데이터 추가

# %% [markdown]
# - 데이터 변경

# %% [markdown]
# ### replace

# %% [markdown]
# ### 참고)기본 파이썬 문법 vs. 판다스 문법

# %% [markdown]
# 기본 파이썬 문법은 inplace 연산이 내장된 경우가 많다. vs. 판다스 문법은 inplace 연산이 내장되지 않은 경우가 많다.

# %% [markdown]
# return이 반영 vs. return이 반영되지 않아

# %%
#
person777_portfolio={}
person777_portfolio.update({'KOSDAQ':'코스닥'})
person777_portfolio
# Out:
# {'KOSDAQ': '코스닥'}

# %% [markdown]
# - 데이터 삭제

# %% [markdown]
# ### drop

# %% [markdown]
# ### 함수 적용 map

# %% [markdown]
# - 하나의 값만 if else

# %% [markdown]
# - series 값들 if else

# %% [markdown]
# `:`와 `if`사이의 값은 `if` 조건이 true일 때 반환값 `else` 오른쪽 같은 false일 때 반환값

# %% [markdown]
# q. 지점(Series)에서 seoul이면 '서울', busan이면 '부산'으로 변경하여라(replace를 이용)

# %% [markdown]
# q. 인구(Series) 3백만보다 작으면 `중도시` 그렇지 않으면 `대도시`로 나타내어라

# %% [markdown]
# ## 딕셔너리 연산 가능

# %% [markdown]
# ## Accessors

# %% [markdown]
# 다른 데이터 유형을 쉽게 조작할 수 있는 접근자

# %% [markdown]
# ### dt

# %% [markdown]
# ### str - slice, contains

# %% [markdown]
# q. time에서 년도만 가져오시오 (str 엑세스를 이용)
